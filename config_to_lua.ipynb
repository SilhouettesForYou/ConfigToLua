# %%
import json
import pandas as pd
import math
import os
import xmltodict
import traceback
from slpp import slpp as lua
from compress_lua_table import CompressLuaTable as compress

# %%
class bcolors:
    OK = '\033[92m' #GREEN
    WARNING = '\033[93m' #YELLOW
    FAIL = '\033[91m' #RED
    RESET = '\033[0m' #RESET COLOR

# %%
types = {}
_types = {}
heads = set()
# with open('SkillEffectTable.json', 'rb') as f:
#     data = json.load(f)
#     for field in data['Fields']:
#         types[field['FieldName']] = field
#         _types[field['FieldName']] = field['FieldTypeName']
#         heads.add(field['FieldName'])

# set(_types.values())
dir = 'E:\WorkSpace\ROGame-dev\config\Table\Configs'
for file in os.listdir(dir):
    with open(os.path.join(dir, file), 'rb') as file:
        data = json.load(file)
        for item in data['TableLocations']:
            print(item['ExcelPath'])
# Out:
# AccessoryTable.csv
# AchievementBadgeTable.csv
# AchievementDetailTable.csv
# AchievementIndexTable.csv
# AchievementPointsAwardTable.csv
# ActionTable.csv
# ActivityComposeTable.csv
# ActivityExtraAwardTable.csv
# ActivitySceneTable.csv
# ActivityTimeScheduleDiceTable.csv
# AffixTable.csv
# AlchemistMake.csv
# AnimationTable.csv
# AttraddMatchTable.csv
# AttraddRecomTable.csv
# AttrDecision.csv
# AttributeAttrLimit.csv
# AttrInfoTable.csv
# AttrPointBaseLvTable.csv
# AttrPointNeed.csv
# AuctionIndexTable.csv
# AuctionTable.csv
# AudioCommonTable.csv
# AudioStoryTable.csv
# AutoAddSkillPointTable.csv
# AutoAddSkilPointDetailTable.csv
# AwardPackTable.csv
# AwardTable.csv
# BagExpandTable.csv
# BarberStyleTable.csv
# BarberTable.csv
# BarrowTable.csv
# BaseLvTable.csv
# BasePackageTable.csv
# BattleCardGlobal.csv
# BattleCardLv.csv
# BattleCardTask.csv
# BattleCardTaskInterface.csv
# BattleGroundLvRangeTable.csv
# BattleVehicleTable.csv
# BGMHouseTable.csv
# BigPicTipTable.csv
# BlackBoxCalcTable.csv
# BlackBoxRecordTable.csv
# BlackBoxValueTable.csv
# BlackCurtainContentTable.csv
# BlackCurtainTable.csv
# BlackWord.csv
# BlessedExperienceTable.csv
# BubbleStyleTable.csv
# BuffEffectTable/BuffEffectTable.csv
# buffeffecttable/BuffEffectPetTable.csv
# Enumerates/BuffStateEnum.csv
# BuffTable/BuffTable.csv
# bufftable/BuffPetTable.csv
# BusinessEventTable.csv
# BusinessGlobalTable.csv
# BusinessNpcInfoTable.csv
# BusinessPriceTable.csv
# BusinessSellTable.csv
# CameraAngleTable.csv
# CameraConfigTable.csv
# CameraContrailTable.csv
# CardAttrListTable.csv
# CardAttrTable.csv
# CardExtraAwardTable.csv
# CardExtraDropTable.csv
# CardLevelTable.csv
# CareerPreviewTable.csv
# CarryItemTable.csv
# CartRemouldTable.csv
# CatRecycleTable.csv
# ChallengeCapra.csv
# ChallengeCapraGame.csv
# ChangeJobTrialTable.csv
# ChargePreferenceTable.csv
# ChatSystemTable.csv
# CheckInCameraTable.csv
# CheckInViewPortTable.csv
# ChooseDescTable.csv
# ClimbAnimTable.csv
# CollectPresentTable.csv
# CollectTable.csv
# CommoditSortTable.csv
# CommoditTable.csv
# CommonGoalsTable.csv
# ComposeClassifyTable.csv
# ComposeTable.csv
# ConvenientAccountTable.csv
# ConvenientBaseJobTable.csv
# ConvenientDetailTable.csv
# CookFoodTable.csv
# CookLevelTable.csv
# CookMenuTable.csv
# CountTable.csv
# CraftingSkillLvUpPriceTable.csv
# CraftingSkillTable.csv
# CreateRole.csv
# CutSceneTable.csv
# CutSceneTalkTable.csv
# DailyActivitiesPushTable.csv
# DailyActivitiesTable.csv
# DanceActionGroupTable.csv
# DanceActionTable.csv
# DanceBGMTable.csv
# DcDifficultyTable.csv
# DcDungeonTable.csv
# DcEntityTable.csv
# DcJumpTable.csv
# DcMonsterTable.csv
# DcOrderTable.csv
# DeathGuideTable.csv
# DefaultEquipTable.csv
# DeviceDetailTable.csv
# DeviceTable.csv
# DialogBgTable.csv
# DialogTabTable.csv
# DoodadTable.csv
# DotHudTable.csv
# DummyMutual.csv
# DungeonAnnouncementTable.csv
# DungeonEntityAttrTable.csv
# DungeonLevelTable.csv
# DungeonRandomTable.csv
# DungeonsDynamicLevelTable.csv
# DungeonsTable.csv
# DungeonStandardAttrTable.csv
# DungeonTargetGroupTable.csv
# DungeonTargetTable.csv
# DynamicAttrAdditionTable.csv
# EffectLodTable.csv
# EffectTable.csv
# ElementAttr.csv
# ElfTable.csv
# ElfTypeTable.csv
# EloNum.csv
# EmotionTable.csv
# EnchantActivityTask.csv
# EnchantReborn.csv
# EndlessTowerJumpTable.csv
# EndlessTowerTable.csv
# EntityComponentTable.csv
# EntityDynamicAttributeTable.csv
# EntityGroupTable.csv
# EntityHandBookLvTable.csv
# EntityHandBookTable.csv
# EntityPrivilegeTable.csv
# EntityTable.csv
# EntityTypeTable.csv
# EntrustActivitiesTable.csv
# EntrustLevelTable.csv
# EntrustPhotoTextTable.csv
# EnvironmentWeatherAudioTable.csv
# EnvironmentWeatherConditionTable.csv
# EnvironmentWeatherEnumTable.csv
# EnvironmentWeatherIconTable.csv
# EnvironmentWeatherModeTable.csv
# EnvironmentWeatherTable.csv
# EnvironmentWeatherTypeTable.csv
# EquipCardSeal.csv
# EquipCardTable.csv
# EquipConsumeTable.csv
# EquipEnchantConsumeTable.csv
# EquipEnchantTable.csv
# EquipJuniorEnchantTable.csv
# EquipSeniorEnchantTable.csv
# EquipForgeTable.csv
# EquipHoleTable.csv
# EquipJuniorEnchantLevel.csv
# EquipMapStringInt.csv
# EquipPositionTable.csv
# EquipRefineTable.csv
# EquipReformCleanTable.csv
# EquipReformSkillTable.csv
# EquipReformTable.csv
# EquipResolveTable.csv
# EquipSeniorEnchantLevel.csv
# EquipStationTable.csv
# EquipTable.csv
# EquipText.csv
# EquipTipsIndex.csv
# EquipTipsTable.csv
# EquipWeaponTable.csv
# ErrorTable.csv
# EventTable.csv
# ExpectPriceTable.csv
# ExpressionPackageTable.csv
# ExpressionTable.csv
# EyeStyleTable.csv
# EyeTable.csv
# FarmAttrTable.csv
# FarmInfoTable.csv
# FashionTable.csv
# FashionThemeTable.csv
# FestivalNoticeTable.csv
# FightGroupTable.csv
# FirstComboSkillTable.csv
# FishTable.csv
# FullItemShowTips.csv
# GachaponPackTable.csv
# GachaponSystemTable.csv
# GameTipsTable.csv
# GarderobeAwardTable.csv
# GatheringTable.csv
# GiftLimitTable.csv
# GiftPackageTable.csv
# GiftRecieveLimitTable.csv
# GiftTable.csv
# GlobalTable.csv
# GlobalTableFight.csv
# GlobalTableSystem.csv
# GlobalTableTask.csv
# GreatSecretAttTable.csv
# GreatSecretDifficultyMap.csv
# GuildActivityTable.csv
# GuildBuildingTable.csv
# GuildContentTable.csv
# GuildCrystalBlessingTable.csv
# GuildCrystalLevelTable.csv
# GuildCrystalTable.csv
# GuildHuntBuffTable.csv
# GuildHuntConfigTable.csv
# GuildIconTable.csv
# GuildManualTable.csv
# GuildNewsTable.csv
# GuildSettingTable.csv
# GuildUpgradingTable.csv
# GvgAreaTable.csv
# GvgCastleTable.csv
# GvgFlagTable.csv
# GvgGuildDungeonMonsterTable.csv
# GvgGuildDungeonTable.csv
# GvgQuestIconTable.csv
# GvgQuestRewardTable.csv
# GvgQuestTable.csv
# GvgSceneTable.csv
# GvgSuppliesTable.csv
# HalloweenPartyTable.csv
# HeroChallengeRandomTable.csv
# HeroChallengeTable.csv
# Enumerates/HitTypeEnum.csv
# HSFxConfigTable.csv
# HSMonsterNumTable.csv
# HSRandomEventTable.csv
# istable/ISAlbumTypeTable.csv
# istable/ISAwardTable.csv
# istable/ISContentTable.csv
# istable/ISContentSplitCutSceneTable.csv
# istable/ISContentSplitMainMemoryTable.csv
# istable/ISContentSplitStoryBoardTable.csv
# istable/ISContentSplitLandscapeTable.csv
# istable/ISContentSplitTermTable.csv
# istable/ISContentSplitLegendActTable.csv
# istable/ISJourneyTypeTable.csv
# istable/ISMemoryTypeTable.csv
# istable/ISUnlockConditionTable.csv
# istable/ISUnlockItemGroupTable.csv
# istable/ISUnlockItemTable.csv
# istable/ISUnlockItemSplitCutSceneTable.csv
# istable/ISUnlockItemSplitMainMemoryTable.csv
# istable/ISUnlockItemSplitStoryBoardTable.csv
# istable/ISUnlockItemSplitLandscapeTable.csv
# istable/ISUnlockItemSplitTermTable.csv
# istable/ISUnlockItemSplitLegendActTable.csv
# ItemAchieveBlackList.csv
# ItemAchievingTypeTable.csv
# ItemDropRate.csv
# ItemFunctionTable.csv
# ItemGroupCDTable.csv
# ItemRadioTable.csv
# ItemRepeatTable.csv
# ItemResolveTable.csv
# ItemSubclassTable.csv
# ItemTable.csv
# ItemTableTask.csv
# ItemTipsImageTable.csv
# ItemTopTable.csv
# ItemUseCountTable.csv
# ItemUseLimitTable.csv
# JobAwardTable.csv
# JobLvTable.csv
# KnowledgeTable.csv
# LabelTable.csv
# LanguageUnicodeTable.csv
# LeaderBoardColumnInfoTable.csv
# LeaderBoardComponentTable.csv
# LeaderBoardFrameTable.csv
# LeaderMethodDetailTable.csv
# LeaderMethodSkillTable.csv
# LeaderMethodTabTable.csv
# LegendActChapter.csv
# LegendActTask.csv
# LegendCollectSuit.csv
# LegendColorSuit.csv
# LegendFashionColorTable.csv
# LevelAwardBonus.csv
# LevelExpBonus.csv
# LevelGiftTable.csv
# LoadingPicTable.csv
# LotteryGroupTable.csv
# LotteryPropTable.csv
# LotterySystemTable.csv
# MagicPaperGiftTable.csv
# MagicPaperTypeTable.csv
# MailTable.csv
# MainUiTable.csv
# MallInterfaceTable.csv
# MallRefreshTable.csv
# MallTable.csv
# MapMatchTable.csv
# MapTable.csv
# MatchDutyTable.csv
# MazeConditionTable.csv
# MazeEventTable.csv
# MazeLoopTable.csv
# MazeOperationTable.csv
# MazeRandomTable.csv
# MazeRoomTable.csv
# MedalAttrTable.csv
# MedalConsumeTable.csv
# MedalLvBonusTable.csv
# MedalServeLvTable.csv
# MedalTable.csv
# MercenaryAttrInfoTable.csv
# MercenaryEquipTable.csv
# MercenaryExpTable.csv
# MercenaryLevelTable.csv
# MercenaryTable.csv
# MercenaryTalentTable.csv
# MerchantGuildTable.csv
# MerchantMakeEnchantTable.csv
# MerchantMakeMaterialsTable.csv
# MessageTable.csv
# MiaoRechargeTable.csv
# MiniMapIconTable.csv
# MonkQTECustomSkillTable.csv
# MonkQTESkillTable.csv
# MonsterDynamicTypeTable.csv
# MonsterRandomTable.csv
# MonsterSuppressTable.csv
# MonthCardTable.csv
# MoonCakeTable.csv
# MouthAttendanceTable.csv
# MultiTalentTable.csv
# MvpTable.csv
# NewKingActivity.csv
# NewPlayerGiftTable.csv
# NewPlayerPrivilege.csv
# NewProfessionGiftTable.csv
# NewProfessionSystemTable.csv
# NoticeLoadTable.csv
# NoticeTable.csv
# NpcActivityTable.csv
# NpcFunctionTable.csv
# NpcTable.csv
# NumLimitTable.csv
# OpenSkillTable.csv
# OpenSystemTable.csv
# OpenWorldCondTable.csv
# OpenWorldIndividualCapTable.csv
# OpenWorldInfluenceTable.csv
# OpenWorldMapEventDescTable.csv
# OpenWorldMapEventTable.csv
# OpenWorldMapTable.csv
# OpenWorldTable.csv
# OrnamentBarterTable.csv
# OrnamentTable.csv
# PassivitySkillEffectTable.csv
# PayGlobalTable.csv
# PaymentSignalTable.csv
# PaymentTable.csv
# PersonalCountTable.csv
# pettable/PetAttrGroupTable.csv
# pettable/PetAttrInfoTable.csv
# pettable/PetCatchTable.csv
# PetDungeonTable.csv
# pettable/PetEggTable.csv
# pettable/PetEquipEnhanceTable.csv
# pettable/PetEquipQualityTable.csv
# pettable/PetEquipSuitTable.csv
# pettable/PetEquipTable.csv
# pettable/PetFeedTable.csv
# pettable/PetLevelTable.csv
# pettable/PetLevelUpAttrTable.csv
# pettable/PetQualityArgs.csv
# pettable/PetSkillBookTable.csv
# pettable/PetSkillQualityArgs.csv
# pettable/PetSkillSlotCostTable.csv
# pettable/PetStatRangeDetail.csv
# pettable/PetStatRangeTable.csv
# PetTable/PetTable.csv
# PhotoFrameTable.csv
# PhotoWallGroupTable.csv
# PostcardDisplayTable.csv
# PostcardStringTable.csv
# PRDQueryTable.csv
# PresentTable.csv
# PrivilegeSystemDesTable.csv
# ProbabilityDetails.csv
# ProbabilityInterface.csv
# ProbabilityModificationTable.csv
# ProbabilityVariationTable.csv
# ProfessionAttr.csv
# ProfessionPreviewTable.csv
# ProfessionTable.csv
# ProfessionTextTable.csv
# ProfilePhotoTable.csv
# PushInformationTable.csv
# PuzzleTable.csv
# QTEGuideTable.csv
# QTESkillTable.csv
# enumerates/RaceEnum.csv
# RandomNameTable.csv
# RandomShowTable.csv
# RankPVPAffixTable.csv
# RankPVPChampionTable.csv
# RankPVPCrossTable.csv
# RankPVPLevelTable.csv
# RankPVPlottery.csv
# RankPVPPoolTable.csv
# RankPVPRewardTable.csv
# RankPVPTaskTable.csv
# RankPVPTeamIconTable.csv
# RateApp.csv
# RebateMonthlyCard.csv
# RechargeGroupTable.csv
# RechargePackageTable.csv
# RechargeTable.csv
# RecipeTable.csv
# RecycleTable.csv
# RedDotCheckTable.csv
# RedDotIndex.csv
# RedPacketLevelMapTable.csv
# RefineOrnamentTransfer.csv
# RefineSuitAttrTable.csv
# RefineTransfer.csv
# RegionTable.csv
# tasktable/RelatedChapterTable.csv
# RelationTable.csv
# ResourceDateTable.csv
# ResourceDungeonTable.csv
# ReturnLoginReward.csv
# ReturnPrivilege.csv
# ReturnTask.csv
# RichTextImageTable.csv
# RoleNurturanceTable.csv
# RouletteTable.csv
# SameScreenShowTable.csv
# SceneObjTable.csv
# SceneTable.csv
# ScrollMakeTable.csv
# SeasonPvpMatchTable.csv
# SeasonTable.csv
# SeasonTotalRechargeTable.csv
# ServerBaseBonusTable.csv
# ServerCountTable.csv
# ServerJobBonusTable.csv
# ServerLevelTable.csv
# ServerLvTable.csv
# ShareTable.csv
# ShopCommoditTable.csv
# ShopTable.csv
# ShowActionTable.csv
# ShowBorderTable.csv
# ShowDecalTable.csv
# ShowExpressionTable.csv
# ShowFaceExpressionTable.csv
# SkillClassRecommandTable.csv
# SkillComboTable.csv
# SkillEffectTable.csv
# SkillEffectPetTable.csv
# SkillEffectUuidTable.csv
# SkillMatchTable.csv
# SkillTable.csv
# SkillPetTable.csv
# SkillTipsLinkTable.csv
# SlimeAttrInfoTable.csv
# SlimeLevelTable.csv
# SlimeTable.csv
# SmallGameTable.csv
# SocialGlobalTable.csv
# SpecialDeviceTable.csv
# SpecialItemTipsTable.csv
# SpecialSceneEffectTable.csv
# SpectatorExtraViewsCapTable.csv
# SpectatorExtraViewsInfoTable.csv
# SpectatorRecThresholdInfoTable.csv
# SpectatorSettingsTable.csv
# SpectatorTypeTable.csv
# StallDetailTable.csv
# StallExpandTable.csv
# StallIndexDescTable.csv
# StallIndexTable.csv
# StallRefreshTable.csv
# StallStackTable.csv
# StateExclusionErrorTable.csv
# StateExclusionTable.csv
# StickersColumnTable.csv
# StickersTable.csv
# StoryBoard.csv
# StoryWordTypeTable.csv
# SuggestionFeedbackCycle.csv
# SuggestionFeedbackType.csv
# SuitTable.csv
# SuperMedalAttrTable.csv
# SuperMedalTable.csv
# TabScreeningTable.csv
# tasktable/TaskAcceptTable.csv
# tasktable/TaskActivityTable.csv
# tasktable/TaskBGMTable.csv
# tasktable/TaskCameraTarget.csv
# tasktable/TaskChangeJobTable.csv
# tasktable/TaskChapterTable.csv
# tasktable/TaskConditionTable.csv
# tasktable/TaskDropTable.csv
# tasktable/TaskEdenLevelTable.csv
# tasktable/TaskExclusiveTable.csv
# tasktable/TaskFlyAcceptTable.csv
# tasktable/TaskGuideNpcTable.csv
# tasktable/TaskItemUseTable.csv
# TaskLifeSkillUnlockTable.csv
# tasktable/TaskOpenUiTable.csv
# tasktable/TaskSceneInteractionTable.csv
# tasktable/TaskSocialDecisionTable.csv
# TaskTable/TaskTable.csv
# tasktable/TaskSplitAdventureTable.csv
# tasktable/TaskSplitBranchTable.csv
# tasktable/TaskSplitCupidTable.csv
# tasktable/TaskSplitDailyTable.csv
# tasktable/TaskSplitDungeonsTable.csv
# tasktable/TaskSplitEdenTable.csv
# tasktable/TaskSplitEntrustTable.csv
# tasktable/TaskSplitGuideTable.csv
# tasktable/TaskSplitGuildTable.csv
# tasktable/TaskSplitInterestingmeetTable.csv
# tasktable/TaskSplitJobTable.csv
# tasktable/TaskSplitLifeTable.csv
# tasktable/TaskSplitPostcardTable.csv
# tasktable/TaskSplitWeekTable.csv
# tasktable/TaskSplitWorldTable.csv
# tasktable/TaskSplitTrackTable.csv
# tasktable/TaskSplitExploreTable.csv
# tasktable/TaskSplitMercenaryTable.csv
# tasktable/TaskSplitChallengeTable.csv
# tasktable/TaskSplitActivityTable.csv
# tasktable/TaskSplitMedalTable.csv
# tasktable/TaskSplitEvilTable.csv
# tasktable/TaskSplitPetTable.csv
# tasktable/TaskTargetLibrary.csv
# tasktable/TaskTypeTable.csv
# TdDifficultyTable.csv
# TdEntityTable.csv
# TdLvRangeTable.csv
# TdManaDropAmountTable.csv
# TdOrderTable.csv
# TdQuestTable.csv
# TdRatingTable.csv
# TdTable.csv
# TdUnitDynamicDataTable.csv
# TdUnitTable.csv
# TdWaveTable.csv
# TeamExpBonus.csv
# TeamScoreTable.csv
# TeamTargetTable.csv
# TempAttrTable.csv
# TemperatureRangeTable.csv
# TheaterTable.csv
# ThemeDungeonsRandomTable.csv
# ThemeDungeonTable.csv
# ThemePartyBGMTable.csv
# ThemePartyTable.csv
# TimeActivityTable.csv
# TimeAxisLuaTable.csv
# TimeGiftTable.csv
# TimeLimitActivityTable.csv
# TimeLimitAttendanceTable.csv
# TimeLimitEvilInvade.csv
# TimeLimitHelmSpeedAward.csv
# TimeLimitTable.csv
# TipsTable.csv
# TitleIndexTable.csv
# TitleTable.csv
# TossTheDiceTable.csv
# TotalRechargeTable.csv
# TreasureDiggingMapTable.csv
# TreasureDiggingTable.csv
# TriggerGiftTable.csv
# TutorialConfigTable.csv
# TutorialIndexTable.csv
# TutorialMarkTable.csv
# TutorialSkillTable.csv
# TutorialTaskTable.csv
# UndirectTeleport.csv
# UserDynamicAttributeTable.csv
# UserDynamicTypeTable.csv
# VehicleAttrTable.csv
# VehicleCollectionAwardTable.csv
# VehicleColorationTable.csv
# VehicleLvTable.csv
# VehicleOrnamentTable.csv
# VehiclePublicTable.csv
# VehicleQualityAttrTable.csv
# VehicleQualityRandomTable.csv
# VehicleQualityTable.csv
# VehicleSpecialAnimTable.csv
# VehicleTable.csv
# VipDoubleTable.csv
# VouchersTable.csv
# WeaponPositionTable.csv
# WelfareFunctionTable.csv
# WheelAddLoad.csv
# WheelAttrTable.csv
# WheelEffects.csv
# WheelProbabilityTable.csv
# WheelReset.csv
# WheelResetConsume.csv
# WheelResolveTable.csv
# WheelSkillTable.csv
# WheelSlotUnlock.csv
# WildBattleConfigTable.csv
# WorldEventTable.csv

# %%
data = pd.read_csv('SkillEffectTable.csv').drop([0])
columns = list(set(data.columns.tolist()) - heads)
data = data.drop(columns=columns)
lua_raw_data = data.to_dict('index')

def check_default(_v, cast, default):
    def is_nan(__v):
        if type(__v) == float:
            return math.isnan(__v)
    return default if is_nan(_v) else cast(_v)


def sequence_to_dict(value, partten, length, cast):
    if value is None or value.strip() == '':
        return value
    array = {}
    sequence = value.split(partten)
    if len(sequence) == length:
        for i in range(length):
            array[i + 1] = cast(sequence[i])
        return array
    return value


def vector_to_list(value, partten, cast, func=None, *args):
    if value is None or value.strip() == '':
        return value
    l = []
    sequence = value.split(partten)
    for s in sequence:
        if func is not None:
            l.append(func(s, *args))
        elif s.strip() != '':
            l.append(cast(s))
    return l


def iteritems_recursive(d):
    t = {}
    for k, v in d.items():
        if isinstance(v, dict):
            t[k] = iteritems_recursive(v)
        else:
            _type = _types[k]
            default = types[k]['DefaultValue']
            if _type == 'string':
                t[k] = check_default(v, str, default)
            elif _type == 'int':
                t[k] = check_default(v, int, default)
            elif _type == 'float':
                t[k] = check_default(v, float, default)
            elif _type == 'bool':
                t[k] = 'false' if v == 0 or v == 'nan' else 'true'
            elif _type == 'Sequence<int, 2>':
                t[k] = sequence_to_dict(check_default(v, str, default), '=', 2, int)
            elif _type == 'vector<Sequence<int, 2>>':
                args = ['=', 2, int]
                t[k] = vector_to_list(check_default(v, str, default), '|', int, sequence_to_dict, *args)
            elif _type == 'vector<Sequence<int, 3>>':
                args = ['=', 3, int]
                t[k] = vector_to_list(check_default(v, str, default), '|', int, sequence_to_dict, *args)
            elif _type == 'vector<int>':
                t[k] = vector_to_list(check_default(v, str, default), '|', int)
            elif _type == 'vector<float>':
                t[k] = vector_to_list(check_default(v, str, default), '|', float)
            elif _type == 'vector<string>':
                t[k] = vector_to_list(check_default(v, str, default), '|', str)
            elif _type == 'vector<vector<int>>':
                args = ['=', int]
                t[k] = vector_to_list(check_default(v, str, default), '|', int, vector_to_list, *args)
            else:
                print(f'`{bcolors.FAIL}' + _type + f'{bcolors.RESET}` is not processed!')
                # return
    return t

table = iteritems_recursive(lua_raw_data)
with open('SkillTable.lua', 'w', encoding='utf-8') as f:
    f.write('return ' + lua.encode(table))

# %%
def is_int(n):
    try:
        int(n)
    except ValueError:
        return False
    return True

def is_float(n):
    try:
        float(n)
    except ValueError:
        return False
    return True

def is_boolean(n):
    if n == 'true' or n == 'false':
        return True
    return False

def to_boolean(n):
    if n == 'true': return True
    elif n == 'false': return False

def filter_key(k):
    return k == '@xmlns:xsd' or k == '@xmlns:xsi'

def iter_xml_recursive(d):
    t = {}
    for k, v in d.items():
        if isinstance(v, dict):
            t[k] = iter_xml_recursive(v)
        elif isinstance(v, list):
            t[k] = iter_xml_recursive({i : v[i] for i in range(len(v))})
        else:
            if v is None:
                t[k] = None
            elif is_int(v):
                t[k] = int(v)
            elif is_float(v):
                t[k] = float(v)
            elif is_boolean(v):
                t[k] = to_boolean(v)
            elif not filter_key(k):
                t[k] = v
                # return
    return t

with open('E:\WorkSpace\ROGame-dev\config\Assets\Resources\SkillData\Activity_XieNengRuQin\Monster_ShenGuan_ShengGuangFaZhen.txt', 'rb') as f:
    table = iter_xml_recursive(dict(xmltodict.parse(f)))
    # print(json.loads(json.dumps(xmltodict.parse(f))))

# %%
from compress_lua_table import CompressLuaTable as compress
compress.process_file(table, 'Monster_ShenGuan_ShengGuangFaZhen')

# %%
dir = 'E:\WorkSpace\ROGame-dev\config\Assets\Resources\SkillData'
EDITOR_DIR = './SkillData/'
if not os.path.exists(EDITOR_DIR):
    os.mkdir(EDITOR_DIR)
for path, dirs, fs in os.walk(dir):
    for f in fs:
        if f.endswith('.txt'):
            # print(f'processing {bcolors.OK}' + os.path.join(path, f) + f'{bcolors.RESET}...')
            # print(os.path.join(EDITOR_DIR + path[len(dir) + 1:], f.replace('.txt', '.lua')))
            _dir = os.path.join(EDITOR_DIR + path[len(dir) + 1:])
            if not os.path.exists(_dir):
                os.mkdir(_dir)
            with open(os.path.join(path, f), 'rb') as file:
                try:
                    table = iter_xml_recursive(dict(xmltodict.parse(file)))
                    with open(os.path.join(_dir, f.replace('.txt', '.lua')), 'w', encoding='utf-8') as w:
                        w.write('local ' + f[:-4] + ' = ' + lua.encode(table) + '\n return ' + f[:-4])
                except Exception as e:
                    print(f'{bcolors.FAIL} error: ' + os.path.join(path, f) + f'{bcolors.RESET}')
                    traceback.print_exc()
# Out:
#  error: E:\WorkSpace\ROGame-dev\config\Assets\Resources\SkillData\Player_Paladin\Player_Paladin_XiSheng.txt
#  error: E:\WorkSpace\ROGame-dev\config\Assets\Resources\SkillData\Player_Paladin\Mount\Player_Paladin_XiSheng.txt
# Traceback (most recent call last):
#   File "C:\Users\MINGZH~1\AppData\Local\Temp/ipykernel_19136/1264675098.py", line 16, in <module>
#     table = iter_xml_recursive(dict(xmltodict.parse(file)))
#   File "D:\Python\Python38\lib\site-packages\xmltodict.py", line 325, in parse
#     parser.ParseFile(xml_input)
# xml.parsers.expat.ExpatError: unclosed token: line 113, column 8
# Traceback (most recent call last):
#   File "C:\Users\MINGZH~1\AppData\Local\Temp/ipykernel_19136/1264675098.py", line 16, in <module>
#     table = iter_xml_recursive(dict(xmltodict.parse(file)))
#   File "D:\Python\Python38\lib\site-packages\xmltodict.py", line 325, in parse
#     parser.ParseFile(xml_input)
# xml.parsers.expat.ExpatError: no element found: line 111, column 42
#  error: E:\WorkSpace\ROGame-dev\config\Assets\Resources\SkillData\Player_Paladin_F\Mount\Player_Paladin_XiSheng.txt
# Traceback (most recent call last):
#   File "C:\Users\MINGZH~1\AppData\Local\Temp/ipykernel_19136/1264675098.py", line 16, in <module>
#     table = iter_xml_recursive(dict(xmltodict.parse(file)))
#   File "D:\Python\Python38\lib\site-packages\xmltodict.py", line 325, in parse
#     parser.ParseFile(xml_input)
# xml.parsers.expat.ExpatError: no element found: line 111, column 42

# %%
import re

str = 'vector<string>'
str2 = 'vector<Sequence<float, 4>>'
pattern = re.compile('([1-9]\d*|string)')
type_pattern = 'Sequence|vector'
print(pattern.findall(str))
print(pattern.match(str2))
print(re.match('vector<[a-z]*>', str))
print(re.match('vector<(Sequence|vector)<[a-z]*, [1-9]\d*>>$', str2))
print(os.cpu_count())
# Out:
# ['string']
# None
# <re.Match object; span=(0, 14), match='vector<string>'>
# <re.Match object; span=(0, 26), match='vector<Sequence<float, 4>>'>
# 16

# %%
# %run main.py -k --f client --csv
# Out:
# processing AccessoryTable.csv ...
# processing AchievementBadgeTable.csv ...
# processing AchievementDetailTable.csv ...
# processing AchievementIndexTable.csv ...
# processing AchievementPointsAwardTable.csv ...
# processing ActionTable.csv ...
# processing ActivityComposeTable.csv ...
# processing ActivityExtraAwardTable.csv ...
# processing ActivitySceneTable.csv ...
# processing ActivityTimeScheduleDiceTable.csv ...
# processing AffixTable.csv ...
# processing AlchemistMake.csv ...
# processing AnimationTable.csv ...
# processing AttraddMatchTable.csv ...
# processing AttraddRecomTable.csv ...
# processing AttrDecision.csv ...
# processing AttributeAttrLimit.csv ...
# processing AttrInfoTable.csv ...
# processing AttrPointBaseLvTable.csv ...
# processing AttrPointNeed.csv ...
# processing AuctionIndexTable.csv ...
# processing AuctionTable.csv ...
# processing AudioCommonTable.csv ...
# processing AudioStoryTable.csv ...
# processing AutoAddSkillPointTable.csv ...
# processing AutoAddSkilPointDetailTable.csv ...
# processing AwardPackTable.csv ...
# processing AwardTable.csv ...
# processing BagExpandTable.csv ...
# processing BarberStyleTable.csv ...
# processing BarberTable.csv ...
# processing BarrowTable.csv ...
# processing BaseLvTable.csv ...
# processing BasePackageTable.csv ...
# processing BattleCardGlobal.csv ...
# processing BattleCardLv.csv ...
# processing BattleCardTask.csv ...
# processing BattleCardTaskInterface.csv ...
# processing BattleGroundLvRangeTable.csv ...
# processing BattleVehicleTable.csv ...
# processing BGMHouseTable.csv ...
# processing BigPicTipTable.csv ...
# processing BlackBoxCalcTable.csv ...
# processing BlackBoxRecordTable.csv ...
# processing BlackBoxValueTable.csv ...
# processing BlackCurtainContentTable.csv ...
# processing BlackCurtainTable.csv ...
# processing BlackWord.csv ...
# processing BlessedExperienceTable.csv ...
# processing BubbleStyleTable.csv ...
# processing BuffEffectTable/BuffEffectTable.csv ...
# processing buffeffecttable/BuffEffectPetTable.csv ...
# processing BuffEffectTable/BuffEffectPVPTable.csv ...
# processing Enumerates/BuffStateEnum.csv ...
# processing BuffTable/BuffTable.csv ...
# processing bufftable/BuffPetTable.csv ...
# processing BuffTable/BuffPVPTable.csv ...
# processing BusinessEventTable.csv ...
# processing BusinessGlobalTable.csv ...
# processing BusinessNpcInfoTable.csv ...
# processing BusinessPriceTable.csv ...
# processing BusinessSellTable.csv ...
# processing CameraAngleTable.csv ...
# processing CameraConfigTable.csv ...
# processing CameraContrailTable.csv ...
# processing CardAttrListTable.csv ...
# processing CardAttrTable.csv ...
# processing CardExtraAwardTable.csv ...
# processing CardExtraDropTable.csv ...
# processing CardLevelTable.csv ...
# processing CareerPreviewTable.csv ...
# processing CarryItemTable.csv ...
# processing CartRemouldTable.csv ...
# processing CatRecycleTable.csv ...
# processing ChallengeCapra.csv ...
# processing ChallengeCapraGame.csv ...
# processing ChangeJobTrialTable.csv ...
# processing ChargePreferenceTable.csv ...
# processing ChatSystemTable.csv ...
# processing CheckInCameraTable.csv ...
# processing CheckInViewPortTable.csv ...
# processing ChooseDescTable.csv ...
# processing ClimbAnimTable.csv ...
# processing CollectPresentTable.csv ...
# processing CollectTable.csv ...
# processing CommoditSortTable.csv ...
# processing CommoditTable.csv ...
# processing CommonGoalsTable.csv ...
# processing ComposeClassifyTable.csv ...
# processing ComposeTable.csv ...
# processing ConvenientAccountTable.csv ...
# processing ConvenientBaseJobTable.csv ...
# processing ConvenientDetailTable.csv ...
# processing CookFoodTable.csv ...
# processing CookLevelTable.csv ...
# processing CookMenuTable.csv ...
# processing CountTable.csv ...
# processing CraftingSkillLvUpPriceTable.csv ...
# processing CraftingSkillTable.csv ...
# processing CreateRole.csv ...
# processing CutSceneTable.csv ...
# processing CutSceneTalkTable.csv ...
# processing DailyActivitiesPushTable.csv ...
# processing DailyActivitiesTable.csv ...
# processing DanceActionGroupTable.csv ...
# processing DanceActionTable.csv ...
# processing DanceBGMTable.csv ...
# processing DcDifficultyTable.csv ...
# processing DcDungeonTable.csv ...
# processing DcEntityTable.csv ...
# processing DcJumpTable.csv ...
# processing DcMonsterTable.csv ...
# processing DcOrderTable.csv ...
# processing DeathGuideTable.csv ...
# processing DefaultEquipTable.csv ...
# processing DeviceDetailTable.csv ...
# processing DeviceTable.csv ...
# processing DialogBgTable.csv ...
# processing DialogTabTable.csv ...
# processing DoodadTable.csv ...
# processing DotHudTable.csv ...
# processing DummyMutual.csv ...
# processing DungeonAnnouncementTable.csv ...
# processing DungeonEntityAttrTable.csv ...
# processing DungeonLevelTable.csv ...
# processing DungeonRandomTable.csv ...
# processing DungeonsDynamicLevelTable.csv ...
# processing DungeonsTable.csv ...
# processing DungeonStandardAttrTable.csv ...
# processing DungeonTargetGroupTable.csv ...
# processing DungeonTargetTable.csv ...
# processing DynamicAttrAdditionTable.csv ...
# processing EffectLodTable.csv ...
# processing EffectTable.csv ...
# processing ElementAttr.csv ...
# processing ElfTable.csv ...
# processing ElfTypeTable.csv ...
# processing EloNum.csv ...
# processing EmotionTable.csv ...
# processing EnchantActivityTask.csv ...
# processing EnchantReborn.csv ...
# processing EndlessTowerJumpTable.csv ...
# processing EndlessTowerTable.csv ...
# processing EntityComponentTable.csv ...
# processing EntityDynamicAttributeTable.csv ...
# processing EntityGroupTable.csv ...
# processing EntityHandBookLvTable.csv ...
# processing EntityHandBookTable.csv ...
# processing EntityPrivilegeTable.csv ...
# processing EntityTable.csv ...
# processing EntityTypeTable.csv ...
# processing EntrustActivitiesTable.csv ...
# processing EntrustLevelTable.csv ...
# processing EntrustPhotoTextTable.csv ...
# processing EnvironmentWeatherAudioTable.csv ...
# processing EnvironmentWeatherConditionTable.csv ...
# processing EnvironmentWeatherEnumTable.csv ...
# processing EnvironmentWeatherIconTable.csv ...
# processing EnvironmentWeatherModeTable.csv ...
# processing EnvironmentWeatherTable.csv ...
# processing EnvironmentWeatherTypeTable.csv ...
# processing EquipCardSeal.csv ...
# processing EquipCardTable.csv ...
# processing EquipConsumeTable.csv ...
# processing EquipEnchantConsumeTable.csv ...
# processing EquipEnchantTable.csv ...
# processing EquipJuniorEnchantTable.csv ...
# processing EquipSeniorEnchantTable.csv ...
# processing EquipForgeTable.csv ...
# processing EquipHoleTable.csv ...
# processing EquipJuniorEnchantLevel.csv ...
# processing EquipMapStringInt.csv ...
# processing EquipPositionTable.csv ...
# processing EquipRefineTable.csv ...
# processing EquipReformCleanTable.csv ...
# processing EquipReformSkillTable.csv ...
# processing EquipReformTable.csv ...
# processing EquipResolveTable.csv ...
# processing EquipSeniorEnchantLevel.csv ...
# processing EquipStationTable.csv ...
# processing EquipTable.csv ...
# processing EquipText.csv ...
# processing EquipTipsIndex.csv ...
# processing EquipTipsTable.csv ...
# processing EquipWeaponTable.csv ...
# processing ErrorTable.csv ...
# processing EventTable.csv ...
# processing ExpectPriceTable.csv ...
# processing ExpressionPackageTable.csv ...
# processing ExpressionTable.csv ...
# processing EyeStyleTable.csv ...
# processing EyeTable.csv ...
# processing FarmAttrTable.csv ...
# processing FarmInfoTable.csv ...
# processing FashionTable.csv ...
# processing FashionThemeTable.csv ...
# processing FestivalNoticeTable.csv ...
# processing FightGroupTable.csv ...
# processing FirstComboSkillTable.csv ...
# processing FishTable.csv ...
# processing FullItemShowTips.csv ...
# processing GachaponPackTable.csv ...
# processing GachaponSystemTable.csv ...
# processing GameTipsTable.csv ...
# processing GarderobeAwardTable.csv ...
# processing GatheringTable.csv ...
# processing GiftLimitTable.csv ...
# processing GiftPackageTable.csv ...
# processing GiftRecieveLimitTable.csv ...
# processing GiftTable.csv ...
# processing GlobalTable.csv ...
# processing GlobalTableFight.csv ...
# processing GlobalTableSystem.csv ...
# processing GlobalTableTask.csv ...
# processing GreatSecretAttTable.csv ...
# processing GreatSecretDifficultyMap.csv ...
# processing GuildActivityTable.csv ...
# processing GuildBuildingTable.csv ...
# processing GuildContentTable.csv ...
# processing GuildCrystalBlessingTable.csv ...
# processing GuildCrystalLevelTable.csv ...
# processing GuildCrystalTable.csv ...
# processing GuildHuntBuffTable.csv ...
# processing GuildHuntConfigTable.csv ...
# processing GuildIconTable.csv ...
# processing GuildManualTable.csv ...
# processing GuildNewsTable.csv ...
# processing GuildSettingTable.csv ...
# processing GuildUpgradingTable.csv ...
# processing GvgAreaTable.csv ...
# processing GvgCastleTable.csv ...
# processing GvgFlagTable.csv ...
# processing GvgGuildDungeonMonsterTable.csv ...
# processing GvgGuildDungeonTable.csv ...
# processing GvgQuestIconTable.csv ...
# processing GvgQuestRewardTable.csv ...
# processing GvgQuestTable.csv ...
# processing GvgSceneTable.csv ...
# processing GvgSuppliesTable.csv ...
# processing HalloweenPartyTable.csv ...
# processing HeroChallengeRandomTable.csv ...
# processing HeroChallengeTable.csv ...
# processing Enumerates/HitTypeEnum.csv ...
# processing HSFxConfigTable.csv ...
# processing HSMonsterNumTable.csv ...
# processing HSRandomEventTable.csv ...
# processing istable/ISAlbumTypeTable.csv ...
# processing istable/ISAwardTable.csv ...
# processing istable/ISContentTable.csv ...
# processing istable/ISContentSplitCutSceneTable.csv ...
# processing istable/ISContentSplitMainMemoryTable.csv ...
# processing istable/ISContentSplitStoryBoardTable.csv ...
# processing istable/ISContentSplitLandscapeTable.csv ...
# processing istable/ISContentSplitTermTable.csv ...
# processing istable/ISContentSplitLegendActTable.csv ...
# processing istable/ISJourneyTypeTable.csv ...
# processing istable/ISMemoryTypeTable.csv ...
# processing istable/ISUnlockConditionTable.csv ...
# processing istable/ISUnlockItemGroupTable.csv ...
# processing istable/ISUnlockItemTable.csv ...
# processing istable/ISUnlockItemSplitCutSceneTable.csv ...
# processing istable/ISUnlockItemSplitMainMemoryTable.csv ...
# processing istable/ISUnlockItemSplitStoryBoardTable.csv ...
# processing istable/ISUnlockItemSplitLandscapeTable.csv ...
# processing istable/ISUnlockItemSplitTermTable.csv ...
# processing istable/ISUnlockItemSplitLegendActTable.csv ...
# processing ItemAchieveBlackList.csv ...
# processing ItemAchievingTypeTable.csv ...
# processing ItemDropRate.csv ...
# processing ItemFunctionTable.csv ...
# processing ItemGroupCDTable.csv ...
# processing ItemRadioTable.csv ...
# processing ItemRepeatTable.csv ...
# processing ItemResolveTable.csv ...
# processing ItemSubclassTable.csv ...
# processing ItemTable.csv ...
# processing ItemTableTask.csv ...
# processing ItemTipsImageTable.csv ...
# processing ItemTopTable.csv ...
# processing ItemUseCountTable.csv ...
# processing ItemUseLimitTable.csv ...
# processing JobAwardTable.csv ...
# processing JobLvTable.csv ...
# processing KnowledgeTable.csv ...
# processing LabelTable.csv ...
# processing LanguageUnicodeTable.csv ...
# processing LeaderBoardColumnInfoTable.csv ...
# processing LeaderBoardComponentTable.csv ...
# processing LeaderBoardFrameTable.csv ...
# processing LeaderMethodDetailTable.csv ...
# processing LeaderMethodSkillTable.csv ...
# processing LeaderMethodTabTable.csv ...
# processing LegendActChapter.csv ...
# processing LegendActTask.csv ...
# processing LegendCollectSuit.csv ...
# processing LegendColorSuit.csv ...
# processing LegendFashionColorTable.csv ...
# processing LevelAwardBonus.csv ...
# processing LevelExpBonus.csv ...
# processing LevelGiftTable.csv ...
# processing LoadingPicTable.csv ...
# processing LotteryGroupTable.csv ...
# processing LotteryPropTable.csv ...
# processing LotterySystemTable.csv ...
# processing MagicPaperGiftTable.csv ...
# processing MagicPaperTypeTable.csv ...
# processing MailTable.csv ...
# processing MainUiTable.csv ...
# processing MallInterfaceTable.csv ...
# processing MallRefreshTable.csv ...
# processing MallTable.csv ...
# processing MapMatchTable.csv ...
# processing MapTable.csv ...
# processing MatchDutyTable.csv ...
# processing MazeConditionTable.csv ...
# processing MazeEventTable.csv ...
# processing MazeLoopTable.csv ...
# processing MazeOperationTable.csv ...
# processing MazeRandomTable.csv ...
# processing MazeRoomTable.csv ...
# processing MedalAttrTable.csv ...
# processing MedalConsumeTable.csv ...
# processing MedalLvBonusTable.csv ...
# processing MedalServeLvTable.csv ...
# processing MedalTable.csv ...
# processing MercenaryAttrInfoTable.csv ...
# processing MercenaryEquipTable.csv ...
# processing MercenaryExpTable.csv ...
# processing MercenaryLevelTable.csv ...
# processing MercenaryTable.csv ...
# processing MercenaryTalentTable.csv ...
# processing MerchantGuildTable.csv ...
# processing MerchantMakeEnchantTable.csv ...
# processing MerchantMakeMaterialsTable.csv ...
# processing MessageTable.csv ...
# processing MiaoRechargeTable.csv ...
# processing MiniMapIconTable.csv ...
# processing MonkQTECustomSkillTable.csv ...
# processing MonkQTESkillTable.csv ...
# processing MonsterDynamicTypeTable.csv ...
# processing MonsterRandomTable.csv ...
# processing MonsterSuppressTable.csv ...
# processing MonthCardTable.csv ...
# processing MoonCakeTable.csv ...
# processing MouthAttendanceTable.csv ...
# processing MultiTalentTable.csv ...
# processing MvpTable.csv ...
# processing NewKingActivity.csv ...
# processing NewPlayerGiftTable.csv ...
# processing NewPlayerPrivilege.csv ...
# processing NewProfessionGiftTable.csv ...
# processing NewProfessionSystemTable.csv ...
# processing NoticeLoadTable.csv ...
# processing NoticeTable.csv ...
# processing NpcActivityTable.csv ...
# processing NpcFunctionTable.csv ...
# processing NpcTable.csv ...
# processing NumLimitTable.csv ...
# processing OpenSkillTable.csv ...
# processing OpenSystemTable.csv ...
# processing OpenWorldCondTable.csv ...
# processing OpenWorldIndividualCapTable.csv ...
# processing OpenWorldInfluenceTable.csv ...
# processing OpenWorldMapEventDescTable.csv ...
# processing OpenWorldMapEventTable.csv ...
# processing OpenWorldMapTable.csv ...
# processing OpenWorldTable.csv ...
# processing OrnamentBarterTable.csv ...
# processing OrnamentTable.csv ...
# processing PassivitySkillEffectTable.csv ...
# processing PayGlobalTable.csv ...
# processing PaymentSignalTable.csv ...
# processing PaymentTable.csv ...
# processing PersonalCountTable.csv ...
# processing pettable/PetAttrGroupTable.csv ...
# processing pettable/PetAttrInfoTable.csv ...
# processing pettable/PetCatchTable.csv ...
# processing PetDungeonTable.csv ...
# processing pettable/PetEggTable.csv ...
# processing pettable/PetEquipEnhanceTable.csv ...
# processing pettable/PetEquipQualityTable.csv ...
# processing pettable/PetEquipSuitTable.csv ...
# processing pettable/PetEquipTable.csv ...
# processing pettable/PetFeedTable.csv ...
# processing pettable/PetLevelTable.csv ...
# processing pettable/PetLevelUpAttrTable.csv ...
# processing pettable/PetQualityArgs.csv ...
# processing pettable/PetSkillBookTable.csv ...
# processing pettable/PetSkillQualityArgs.csv ...
# processing pettable/PetSkillSlotCostTable.csv ...
# processing pettable/PetStatRangeDetail.csv ...
# processing pettable/PetStatRangeTable.csv ...
# processing PetTable/PetTable.csv ...
# processing PhotoFrameTable.csv ...
# processing PhotoWallGroupTable.csv ...
# processing PostcardDisplayTable.csv ...
# processing PostcardStringTable.csv ...
# processing PRDQueryTable.csv ...
# processing PresentTable.csv ...
# processing PrivilegeSystemDesTable.csv ...
# processing ProbabilityDetails.csv ...
# processing ProbabilityInterface.csv ...
# processing ProbabilityModificationTable.csv ...
# processing ProbabilityVariationTable.csv ...
# processing ProfessionAttr.csv ...
# processing ProfessionPreviewTable.csv ...
# processing ProfessionTable.csv ...
# processing ProfessionTextTable.csv ...
# processing ProfilePhotoTable.csv ...
# processing PushInformationTable.csv ...
# processing PuzzleTable.csv ...
# processing QTEGuideTable.csv ...
# processing QTESkillTable.csv ...
# processing enumerates/RaceEnum.csv ...
# processing RandomNameTable.csv ...
# processing RandomShowTable.csv ...
# processing RankPVPAffixTable.csv ...
# processing RankPVPChampionTable.csv ...
# processing RankPVPCrossTable.csv ...
# processing RankPVPLevelTable.csv ...
# processing RankPVPlottery.csv ...
# processing RankPVPPoolTable.csv ...
# processing RankPVPRewardTable.csv ...
# processing RankPVPTaskTable.csv ...
# processing RankPVPTeamIconTable.csv ...
# processing RateApp.csv ...
# processing RebateMonthlyCard.csv ...
# processing RechargeGroupTable.csv ...
# processing RechargePackageTable.csv ...
# processing RechargeTable.csv ...
# processing RecipeTable.csv ...
# processing RecycleTable.csv ...
# processing RedDotCheckTable.csv ...
# processing RedDotIndex.csv ...
# processing RedPacketLevelMapTable.csv ...
# processing RefineOrnamentTransfer.csv ...
# processing RefineSuitAttrTable.csv ...
# processing RefineTransfer.csv ...
# processing RegionTable.csv ...
# processing tasktable/RelatedChapterTable.csv ...
# processing RelationTable.csv ...
# processing ResourceDateTable.csv ...
# processing ResourceDungeonTable.csv ...
# processing ReturnLoginReward.csv ...
# processing ReturnPrivilege.csv ...
# processing ReturnTask.csv ...
# processing RichTextImageTable.csv ...
# processing RoleNurturanceTable.csv ...
# processing RouletteTable.csv ...
# processing SameScreenShowTable.csv ...
# processing SceneObjTable.csv ...
# processing SceneTable.csv ...
# processing ScrollMakeTable.csv ...
# processing SeasonPvpMatchTable.csv ...
# processing SeasonTable.csv ...
# processing SeasonTotalRechargeTable.csv ...
# processing ServerBaseBonusTable.csv ...
# processing ServerCountTable.csv ...
# processing ServerJobBonusTable.csv ...
# processing ServerLevelTable.csv ...
# processing ServerLvTable.csv ...
# processing ShareTable.csv ...
# processing ShopCommoditTable.csv ...
# processing ShopTable.csv ...
# processing ShowActionTable.csv ...
# processing ShowBorderTable.csv ...
# processing ShowDecalTable.csv ...
# processing ShowExpressionTable.csv ...
# processing ShowFaceExpressionTable.csv ...
# processing SkillClassRecommandTable.csv ...
# processing SkillComboTable.csv ...
# processing SkillEffectTable.csv ...
# processing SkillEffectPetTable.csv ...
# processing SkillEffectUuidTable.csv ...
# processing SkillMatchTable.csv ...
# processing SkillTable.csv ...
# processing SkillPetTable.csv ...
# processing SkillTipsLinkTable.csv ...
# processing SlimeAttrInfoTable.csv ...
# processing SlimeLevelTable.csv ...
# processing SlimeTable.csv ...
# processing SmallGameTable.csv ...
# processing SocialGlobalTable.csv ...
# processing SpecialDeviceTable.csv ...
# processing SpecialItemTipsTable.csv ...
# processing SpecialSceneEffectTable.csv ...
# processing SpectatorExtraViewsCapTable.csv ...
# processing SpectatorExtraViewsInfoTable.csv ...
# processing SpectatorRecThresholdInfoTable.csv ...
# processing SpectatorSettingsTable.csv ...
# processing SpectatorTypeTable.csv ...
# processing StallDetailTable.csv ...
# processing StallExpandTable.csv ...
# processing StallIndexDescTable.csv ...
# processing StallIndexTable.csv ...
# processing StallRefreshTable.csv ...
# processing StallStackTable.csv ...
# processing StateExclusionErrorTable.csv ...
# processing StateExclusionTable.csv ...
# processing StickersColumnTable.csv ...
# processing StickersTable.csv ...
# processing StoryBoard.csv ...
# processing StoryWordTypeTable.csv ...
# processing SuggestionFeedbackCycle.csv ...
# processing SuggestionFeedbackType.csv ...
# processing SuitTable.csv ...
# processing SuperMedalAttrTable.csv ...
# processing SuperMedalTable.csv ...
# processing TabScreeningTable.csv ...
# processing tasktable/TaskAcceptTable.csv ...
# processing tasktable/TaskActivityTable.csv ...
# processing tasktable/TaskBGMTable.csv ...
# processing tasktable/TaskCameraTarget.csv ...
# processing tasktable/TaskChangeJobTable.csv ...
# processing tasktable/TaskChapterTable.csv ...
# processing tasktable/TaskConditionTable.csv ...
# processing tasktable/TaskDropTable.csv ...
# processing tasktable/TaskEdenLevelTable.csv ...
# processing tasktable/TaskExclusiveTable.csv ...
# processing tasktable/TaskFlyAcceptTable.csv ...
# processing tasktable/TaskGuideNpcTable.csv ...
# processing tasktable/TaskItemUseTable.csv ...
# processing TaskLifeSkillUnlockTable.csv ...
# processing tasktable/TaskOpenUiTable.csv ...
# processing tasktable/TaskSceneInteractionTable.csv ...
# processing tasktable/TaskSocialDecisionTable.csv ...
# processing TaskTable/TaskTable.csv ...
# processing tasktable/TaskSplitAdventureTable.csv ...
# processing tasktable/TaskSplitBranchTable.csv ...
# processing tasktable/TaskSplitCupidTable.csv ...
# processing tasktable/TaskSplitDailyTable.csv ...
# processing tasktable/TaskSplitDungeonsTable.csv ...
# processing tasktable/TaskSplitEdenTable.csv ...
# processing tasktable/TaskSplitEntrustTable.csv ...
# processing tasktable/TaskSplitGuideTable.csv ...
# processing tasktable/TaskSplitGuildTable.csv ...
# processing tasktable/TaskSplitInterestingmeetTable.csv ...
# processing tasktable/TaskSplitJobTable.csv ...
# processing tasktable/TaskSplitLifeTable.csv ...
# processing tasktable/TaskSplitPostcardTable.csv ...
# processing tasktable/TaskSplitWeekTable.csv ...
# processing tasktable/TaskSplitWorldTable.csv ...
# processing tasktable/TaskSplitTrackTable.csv ...
# processing tasktable/TaskSplitExploreTable.csv ...
# processing tasktable/TaskSplitMercenaryTable.csv ...
# processing tasktable/TaskSplitChallengeTable.csv ...
# processing tasktable/TaskSplitActivityTable.csv ...
# processing tasktable/TaskSplitMedalTable.csv ...
# processing tasktable/TaskSplitEvilTable.csv ...
# processing tasktable/TaskSplitPetTable.csv ...
# processing tasktable/TaskTargetLibrary.csv ...
# processing tasktable/TaskTypeTable.csv ...
# processing TdDifficultyTable.csv ...
# processing TdEntityTable.csv ...
# processing TdLvRangeTable.csv ...
# processing TdManaDropAmountTable.csv ...
# processing TdOrderTable.csv ...
# processing TdQuestTable.csv ...
# processing TdRatingTable.csv ...
# processing TdTable.csv ...
# processing TdUnitDynamicDataTable.csv ...
# processing TdUnitTable.csv ...
# processing TdWaveTable.csv ...
# processing TeamExpBonus.csv ...
# processing TeamScoreTable.csv ...
# processing TeamTargetTable.csv ...
# processing TempAttrTable.csv ...
# processing TemperatureRangeTable.csv ...
# processing TheaterTable.csv ...
# processing ThemeDungeonsRandomTable.csv ...
# processing ThemeDungeonTable.csv ...
# processing ThemePartyBGMTable.csv ...
# processing ThemePartyTable.csv ...
# processing TimeActivityTable.csv ...
# processing TimeAxisLuaTable.csv ...
# processing TimeGiftTable.csv ...
# processing TimeLimitActivityTable.csv ...
# processing TimeLimitAttendanceTable.csv ...
# processing TimeLimitEvilInvade.csv ...
# processing TimeLimitHelmSpeedAward.csv ...
# processing TimeLimitTable.csv ...
# processing TipsTable.csv ...
# processing TitleIndexTable.csv ...
# processing TitleTable.csv ...
# processing TossTheDiceTable.csv ...
# processing TotalRechargeTable.csv ...
# processing TreasureDiggingMapTable.csv ...
# processing TreasureDiggingTable.csv ...
# processing TriggerGiftTable.csv ...
# processing TutorialConfigTable.csv ...
# processing TutorialIndexTable.csv ...
# processing TutorialMarkTable.csv ...
# processing TutorialSkillTable.csv ...
# processing TutorialTaskTable.csv ...
# processing UndirectTeleport.csv ...
# processing UserDynamicAttributeTable.csv ...
# processing UserDynamicTypeTable.csv ...
# processing VehicleAttrTable.csv ...
# processing VehicleCollectionAwardTable.csv ...
# processing VehicleColorationTable.csv ...
# processing VehicleLvTable.csv ...
# processing VehicleOrnamentTable.csv ...
# processing VehiclePublicTable.csv ...
# processing VehicleQualityAttrTable.csv ...
# processing VehicleQualityRandomTable.csv ...
# processing VehicleQualityTable.csv ...
# processing VehicleSpecialAnimTable.csv ...
# processing VehicleTable.csv ...
# processing VipDoubleTable.csv ...
# processing VouchersTable.csv ...
# processing WeaponPositionTable.csv ...
# processing WelfareFunctionTable.csv ...
# processing WheelAddLoad.csv ...
# processing WheelAttrTable.csv ...
# processing WheelEffects.csv ...
# processing WheelProbabilityTable.csv ...
# processing WheelReset.csv ...
# processing WheelResetConsume.csv ...
# processing WheelResolveTable.csv ...
# processing WheelSkillTable.csv ...
# processing WheelSlotUnlock.csv ...
# processing WildBattleConfigTable.csv ...
# processing WorldEventTable.csv ...

# %%
import subprocess

_dir = 'Table-client/'
for file in os.listdir(_dir):
    func = 'optimizer(\"{0}\", \"{1}\")'.format(_dir + file[:-4], file[:-4])
    try:
        result = subprocess.check_output(['lua53', '-l', 'DataTableOptimizer', '-e', func])
    except Exception as e :
        print(file)

# %%
import subprocess
import traceback


for file in os.listdir('./Table-client'):
    func = '_load(\"{0}\")'.format('Table-client.' + file[:-4])
    try:
        result = subprocess.check_output(['lua53', '-l', 'test', '-e', func])
    except Exception as e :
        print(file)
        # pass
        # traceback.print_exc()

# %%
import re
import sys
from numbers import Number
from slpp import slpp as lua
import six
import json


tab = ''
newline = ''
depth = 0

def __encode(obj):
    s = ''
    global depth
    global newline
    global tab
    if isinstance(obj, str):
        s += '"%s"' % obj.replace(r'"', r'\"')
    elif six.PY2 and isinstance(obj, unicode):
        s += '"%s"' % obj.encode('utf-8').replace(r'"', r'\"')
    elif six.PY3 and isinstance(obj, bytes):
        s += '"{}"'.format(''.join(r'\x{:02x}'.format(c) for c in obj))
    elif isinstance(obj, bool):
        s += str(obj).lower()
    elif obj is None:
        # pass
        s += 'nil'
    elif isinstance(obj, Number):
        s += str(obj)
    elif isinstance(obj, dict):
        depth += 1
        s += "{"
        key_list = ['%s' for k in obj.keys()]
        contents = [(key + '%s') % (k, __encode(v)) for (k, v), key in zip(obj.items(), key_list)]
        s += (',%s' % newline).join(contents)
        depth -= 1
        s += "}"
    return s

def encode(obj):
    s = ''
    if isinstance(obj, str):
        s += '"%s"' % obj.replace(r'"', r'\"')
    elif isinstance(obj, bool):
        s += str(obj).lower()
    elif obj is None:
        s += 'nil'
    elif isinstance(obj, Number):
        s += str(obj)
    elif isinstance(obj, dict):
        s += "{"
        contents = [encode(v) for _, v in obj.items()]
        s += ','.join(contents)
        s += "}"
    return s


def compress_lua(obj, name):
    s = 'local {} = {\n'.format(name)
    for _, value in obj.items():
        line = '\t{'
        for k, items in value.items():
            line += encode(items) + ','
        line = line[:-1] + '},\n'
        s += line

    # define default table
    s += '}\n\nlocal __default_table = {'
    for key, _ in indices.items():
        s += key + ','
    s = s[:-1] + '}\n'

    # add postfix

    return s

    
with open('./Table-client/AwardPackTable.lua', 'r') as f:
    table_name = 'AwardPackTable'
    text = f.read()
    obj = lua.decode(text)
    res = compress_lua(obj)
    res = 'local {} = '.format(table_name) + res
    # res = __encode(obj)
    with open('test.lua', 'w', encoding='utf-8') as w:
        w.write(res)
        w.write("\ndo\n")
        w.write("\tlocal base = {__index = __default_table, __newindex = function() error(\"Attempt to modify read-only table\") end}\n")
        w.write("\tfor k, v in pairs(%s) do\n" % (table_name))
        w.write("\t\tsetmetatable(v, base)\n")
        w.write("\tend\n")
        w.write("\tbase.__metatable = false\n")
        w.write("end\n")
        w.write("\nreturn %s\n" % (table_name))
