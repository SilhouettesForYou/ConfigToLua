# %%
import json
import pandas as pd
import math
import os
import xmltodict
import traceback
from slpp import slpp as lua
from compress_lua_table import CompressLuaTable as compress

# %%
class bcolors:
    OK = '\033[92m' #GREEN
    WARNING = '\033[93m' #YELLOW
    FAIL = '\033[91m' #RED
    RESET = '\033[0m' #RESET COLOR

# %%
types = {}
_types = {}
heads = set()
# with open('SkillEffectTable.json', 'rb') as f:
#     data = json.load(f)
#     for field in data['Fields']:
#         types[field['FieldName']] = field
#         _types[field['FieldName']] = field['FieldTypeName']
#         heads.add(field['FieldName'])

# set(_types.values())
dir = 'E:\WorkSpace\ROGame-dev\config\Table\Configs'
for file in os.listdir(dir):
    with open(os.path.join(dir, file), 'rb') as file:
        data = json.load(file)
        for item in data['TableLocations']:
            print(item['ExcelPath'])

# %%
data = pd.read_csv('SkillEffectTable.csv').drop([0])
columns = list(set(data.columns.tolist()) - heads)
data = data.drop(columns=columns)
lua_raw_data = data.to_dict('index')

def check_default(_v, cast, default):
    def is_nan(__v):
        if type(__v) == float:
            return math.isnan(__v)
    return default if is_nan(_v) else cast(_v)


def sequence_to_dict(value, partten, length, cast):
    if value is None or value.strip() == '':
        return value
    array = {}
    sequence = value.split(partten)
    if len(sequence) == length:
        for i in range(length):
            array[i + 1] = cast(sequence[i])
        return array
    return value


def vector_to_list(value, partten, cast, func=None, *args):
    if value is None or value.strip() == '':
        return value
    l = []
    sequence = value.split(partten)
    for s in sequence:
        if func is not None:
            l.append(func(s, *args))
        elif s.strip() != '':
            l.append(cast(s))
    return l


def iteritems_recursive(d):
    t = {}
    for k, v in d.items():
        if isinstance(v, dict):
            t[k] = iteritems_recursive(v)
        else:
            _type = _types[k]
            default = types[k]['DefaultValue']
            if _type == 'string':
                t[k] = check_default(v, str, default)
            elif _type == 'int':
                t[k] = check_default(v, int, default)
            elif _type == 'float':
                t[k] = check_default(v, float, default)
            elif _type == 'bool':
                t[k] = 'false' if v == 0 or v == 'nan' else 'true'
            elif _type == 'Sequence<int, 2>':
                t[k] = sequence_to_dict(check_default(v, str, default), '=', 2, int)
            elif _type == 'vector<Sequence<int, 2>>':
                args = ['=', 2, int]
                t[k] = vector_to_list(check_default(v, str, default), '|', int, sequence_to_dict, *args)
            elif _type == 'vector<Sequence<int, 3>>':
                args = ['=', 3, int]
                t[k] = vector_to_list(check_default(v, str, default), '|', int, sequence_to_dict, *args)
            elif _type == 'vector<int>':
                t[k] = vector_to_list(check_default(v, str, default), '|', int)
            elif _type == 'vector<float>':
                t[k] = vector_to_list(check_default(v, str, default), '|', float)
            elif _type == 'vector<string>':
                t[k] = vector_to_list(check_default(v, str, default), '|', str)
            elif _type == 'vector<vector<int>>':
                args = ['=', int]
                t[k] = vector_to_list(check_default(v, str, default), '|', int, vector_to_list, *args)
            else:
                print(f'`{bcolors.FAIL}' + _type + f'{bcolors.RESET}` is not processed!')
                # return
    return t

table = iteritems_recursive(lua_raw_data)
with open('SkillTable.lua', 'w', encoding='utf-8') as f:
    f.write('return ' + lua.encode(table))

# %%
def is_int(n):
    try:
        int(n)
    except ValueError:
        return False
    return True

def is_float(n):
    try:
        float(n)
    except ValueError:
        return False
    return True

def is_boolean(n):
    if n == 'true' or n == 'false':
        return True
    return False

def to_boolean(n):
    if n == 'true': return True
    elif n == 'false': return False

def filter_key(k):
    return k == '@xmlns:xsd' or k == '@xmlns:xsi'

def iter_xml_recursive(d):
    t = {}
    for k, v in d.items():
        if isinstance(v, dict):
            t[k] = iter_xml_recursive(v)
        elif isinstance(v, list):
            t[k] = iter_xml_recursive({i : v[i] for i in range(len(v))})
        else:
            if v is None:
                t[k] = None
            elif is_int(v):
                t[k] = int(v)
            elif is_float(v):
                t[k] = float(v)
            elif is_boolean(v):
                t[k] = to_boolean(v)
            elif not filter_key(k):
                t[k] = v
                # return
    return t

with open('E:\WorkSpace\ROGame-dev\config\Assets\Resources\SkillData\Activity_XieNengRuQin\Monster_ShenGuan_ShengGuangFaZhen.txt', 'rb') as f:
    table = iter_xml_recursive(dict(xmltodict.parse(f)))
    # print(json.loads(json.dumps(xmltodict.parse(f))))

# %%
from compress_lua_table import CompressLuaTable as compress
compress.process_file(table, 'Monster_ShenGuan_ShengGuangFaZhen')

# %%
dir = 'E:\WorkSpace\ROGame-dev\config\Assets\Resources\SkillData'
EDITOR_DIR = './SkillData/'
if not os.path.exists(EDITOR_DIR):
    os.mkdir(EDITOR_DIR)
for path, dirs, fs in os.walk(dir):
    for f in fs:
        if f.endswith('.txt'):
            # print(f'processing {bcolors.OK}' + os.path.join(path, f) + f'{bcolors.RESET}...')
            # print(os.path.join(EDITOR_DIR + path[len(dir) + 1:], f.replace('.txt', '.lua')))
            _dir = os.path.join(EDITOR_DIR + path[len(dir) + 1:])
            if not os.path.exists(_dir):
                os.mkdir(_dir)
            with open(os.path.join(path, f), 'rb') as file:
                try:
                    table = iter_xml_recursive(dict(xmltodict.parse(file)))
                    with open(os.path.join(_dir, f.replace('.txt', '.lua')), 'w', encoding='utf-8') as w:
                        w.write('local ' + f[:-4] + ' = ' + lua.encode(table) + '\n return ' + f[:-4])
                except Exception as e:
                    print(f'{bcolors.FAIL} error: ' + os.path.join(path, f) + f'{bcolors.RESET}')
                    traceback.print_exc()

# %%
import re

str = 'vector<string>'
str2 = 'vector<Sequence<float, 4>>'
pattern = re.compile('([1-9]\d*|string)')
type_pattern = 'Sequence|vector'
print(pattern.findall(str))
print(pattern.match(str2))
print(re.match('vector<[a-z]*>', str))
print(re.match('vector<(Sequence|vector)<[a-z]*, [1-9]\d*>>$', str2))
print(os.cpu_count())
re.match('_size=[1-9]\d*', '_size=1')
re.match('_t=[s|v]', '_t=v')

# %%
# %run main.py --f client --csv

# %%
import subprocess

_dir = 'Table-client/'
for file in os.listdir(_dir):
    func = 'optimizer(\"{0}\", \"{1}\")'.format(_dir + file[:-4], file[:-4])
    try:
        result = subprocess.check_output(['lua53', '-l', 'DataTableOptimizer', '-e', func])
    except Exception as e :
        print(file)

# %%
import subprocess
import traceback


for file in os.listdir('./table-client'):
    func = '_load("{0}")'.format('table-client.' + file[:-4])
    try:
        print(func)
        result = subprocess.check_output(['lua', '-l', 'test', '-e', func])
    except Exception as e :
        print(e)
        # pass
        # traceback.print_exc()
    result = subprocess.check_output(['lua', '-l', 'test', '-e', func])
# Out:
# _load("table-client.AccessoryTable")
# [WinError 2] 系统找不到指定的文件。
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\MINGZH~1\AppData\Local\Temp/ipykernel_15288/296455303.py in <module>
#      12         # pass
#      13         # traceback.print_exc()
# ---> 14     result = subprocess.check_output(['lua', '-l', 'test', '-e', func])
#      15
#
# ~\AppData\Local\Programs\Python\Python310\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     418         kwargs['input'] = empty
#     419
# --> 420     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     421                **kwargs).stdout
#     422
#
# ~\AppData\Local\Programs\Python\Python310\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     499         kwargs['stderr'] = PIPE
#     500
# --> 501     with Popen(*popenargs, **kwargs) as process:
#     502         try:
#     503             stdout, stderr = process.communicate(input, timeout=timeout)
#
# ~\AppData\Local\Programs\Python\Python310\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     964                             encoding=encoding, errors=errors)
#     965
# --> 966             self._execute_child(args, executable, preexec_fn, close_fds,
#     967                                 pass_fds, cwd, env,
#     968                                 startupinfo, creationflags, shell,
#
# ~\AppData\Local\Programs\Python\Python310\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1433             # Start the process
#    1434             try:
# -> 1435                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1436                                          # no special security
#    1437                                          None, None,
#
# FileNotFoundError: [WinError 2] 系统找不到指定的文件。

# %%
import re
import sys
from numbers import Number
from slpp import slpp as lua
import six
import json


tab = ''
newline = ''
depth = 0

def __encode(obj):
    s = ''
    global depth
    global newline
    global tab
    if isinstance(obj, str):
        s += '"%s"' % obj.replace(r'"', r'\"')
    elif six.PY2 and isinstance(obj, unicode):
        s += '"%s"' % obj.encode('utf-8').replace(r'"', r'\"')
    elif six.PY3 and isinstance(obj, bytes):
        s += '"{}"'.format(''.join(r'\x{:02x}'.format(c) for c in obj))
    elif isinstance(obj, bool):
        s += str(obj).lower()
    elif obj is None:
        # pass
        s += 'nil'
    elif isinstance(obj, Number):
        s += str(obj)
    elif isinstance(obj, dict):
        depth += 1
        s += "{"
        key_list = ['%s' for k in obj.keys()]
        contents = [(key + '%s') % (k, __encode(v)) for (k, v), key in zip(obj.items(), key_list)]
        s += (',%s' % newline).join(contents)
        depth -= 1
        s += "}"
    return s

def encode(obj):
    s = ''
    if isinstance(obj, str):
        s += '"%s"' % obj.replace(r'"', r'\"')
    elif isinstance(obj, bool):
        s += str(obj).lower()
    elif obj is None:
        s += 'nil'
    elif isinstance(obj, Number):
        s += str(obj)
    elif isinstance(obj, dict):
        s += "{"
        contents = [encode(v) for _, v in obj.items()]
        s += ','.join(contents)
        s += "}"
    return s


def compress_lua(obj, name):
    s = 'local {} = {\n'.format(name)
    for _, value in obj.items():
        line = '\t{'
        for k, items in value.items():
            line += encode(items) + ','
        line = line[:-1] + '},\n'
        s += line

    # define default table
    s += '}\n\nlocal __default_table = {'
    for key, _ in indices.items():
        s += key + ','
    s = s[:-1] + '}\n'

    # add postfix

    return s

    
with open('./Table-client/AwardPackTable.lua', 'r') as f:
    table_name = 'AwardPackTable'
    text = f.read()
    obj = lua.decode(text)
    res = compress_lua(obj)
    res = 'local {} = '.format(table_name) + res
    # res = __encode(obj)
    with open('test.lua', 'w', encoding='utf-8') as w:
        w.write(res)
        w.write("\ndo\n")
        w.write("\tlocal base = {__index = __default_table, __newindex = function() error(\"Attempt to modify read-only table\") end}\n")
        w.write("\tfor k, v in pairs(%s) do\n" % (table_name))
        w.write("\t\tsetmetatable(v, base)\n")
        w.write("\tend\n")
        w.write("\tbase.__metatable = false\n")
        w.write("end\n")
        w.write("\nreturn %s\n" % (table_name))

# %%
import re
from CppHeaderParser import CppHeader, CppParseError


class bcolors:
    OK = '\033[92m' #GREEN
    WARNING = '\033[93m' #YELLOW
    FAIL = '\033[91m' #RED
    RESET = '\033[0m' #RESET COLOR


def filter_include(lines):
    res = ''
    for line in lines:
        if line.strip().startswith('$'): res += line.replace('$', '')
        else: res += line
    return res


def pascal_to_snake(camel: str):
    snake = re.sub(r'(?P<key>[A-Z])', r'_\g<key>',camel)
    return snake.lower().strip('_')


def parse_cpp(name, header):
    namespaces = set()
    classes = {}
    output_namespaces = 4 * ' ' + '// {}\n'.format(name)
    output_classes = 4 * ' ' + '// classes\n'
    output_variables = 4 * ' ' + '// variables\n'
    output_methods = 4 * ' ' + '// methods\n'
    output_enums = 4 * ' ' + '// enums\n'

    # variables & methods
    for class_name in header.classes.keys():
        # print(header.classes[class_name])
        namespace = header.classes[class_name]['namespace']
        namespaces.add(namespace)
        classes[class_name] = namespace
        
        for method in header.classes[class_name]['methods']['private']:
            output_methods += 4 * ' ' + '{}_proxy[\"{}\"] = &{}::{}::{};\n'.format(pascal_to_snake(class_name), method['name'], namespace, class_name, method['name'])

        for property in header.classes[class_name]['properties']['public']:
            output_variables += 4 * ' ' + '{}_proxy[\"{}\"] = &{}::{}::{};\n'.format(pascal_to_snake(class_name), property['name'], namespace, class_name, property['name'])

        for property in header.classes[class_name]['properties']['private']:
            output_variables += 4 * ' ' + '{}_proxy[\"{}\"] = &{}::{}::{};\n'.format(pascal_to_snake(class_name), property['name'], namespace, class_name, property['name'])

    # namespace
    for namespace in namespaces:
        output_namespaces += 4 * ' ' + 'sol::table {} = l.create_named_table(\"{}\");\n'.format(pascal_to_snake(namespace), namespace)

    # classes
    for class_, namespace in classes.items():
        output_classes += 4 * ' ' + 'auto {}_proxy = {}.new_usertype<{}::{}>(\"{}\");\n'.format(pascal_to_snake(class_), pascal_to_snake(namespace), namespace, class_, class_)

    # enums
    for enum in header.enums:
        s = ''
        enum_str = 8 * ' ' + '\"{}\", {}::{}::{}, \n'
        namespace = enum['namespace'][:-2]
        for variable in enum['values']:
            s += enum_str.format(variable['name'], namespace, enum['name'], variable['name'])
        # print(s[:-1])
        output_enums += 4 * ' ' + '{}.new_enum(\"{}\",\n{}\n);\n'.format(pascal_to_snake(namespace), enum['name'], s[:-1])

    print(output_namespaces, output_classes, output_methods, output_variables, output_enums)


with open('.config', 'r') as f:
    lines = f.readlines()
    dir_config = lines[2].strip()
    _dir = dir_config.split('#')[1]
    for file in os.listdir(_dir):
        if file.endswith('.pkg'):
            if file != 'buff_def.pkg': continue
            with open(os.path.join(_dir, file), 'r', encoding='utf-8') as pkg:
                content = filter_include(pkg.readlines())
                try:
                    cpp_header = CppHeader(content, argType='string', encoding='utf-8')
                    parse_cpp(file, cpp_header)
                except CppParseError as e:
                    # print(e)
                    print(f'{bcolors.FAIL}' + file + f'{bcolors.RESET}')
# Out:
#     // buff_def.pkg
#     sol::table r_o_game_libs = l.create_named_table("ROGameLibs");
#      // classes
#     auto equip_single_proxy = r_o_game_libs.new_usertype<ROGameLibs::EquipSingle>("EquipSingle");
#     auto buff_lua_info_proxy = r_o_game_libs.new_usertype<ROGameLibs::BuffLuaInfo>("BuffLuaInfo");
#      // methods
#     buff_lua_info_proxy["GetExtraParamByName"] = &ROGameLibs::BuffLuaInfo::GetExtraParamByName;
#     buff_lua_info_proxy["GetChangeEquipListCount"] = &ROGameLibs::BuffLuaInfo::GetChangeEquipListCount;
#     buff_lua_info_proxy["GetEquipChangeInfo"] = &ROGameLibs::BuffLuaInfo::GetEquipChangeInfo;
#     buff_lua_info_proxy["GetLuaEnterEntity"] = &ROGameLibs::BuffLuaInfo::GetLuaEnterEntity;
#     buff_lua_info_proxy["GetLuaFirerEntity"] = &ROGameLibs::BuffLuaInfo::GetLuaFirerEntity;
#     buff_lua_info_proxy["GetLuaAttackTarget"] = &ROGameLibs::BuffLuaInfo::GetLuaAttackTarget;
#     buff_lua_info_proxy["SkillEffectIdToSkillUuid"] = &ROGameLibs::BuffLuaInfo::SkillEffectIdToSkillUuid;
#     buff_lua_info_proxy["GetCurrSkillUuid"] = &ROGameLibs::BuffLuaInfo::GetCurrSkillUuid;
#     buff_lua_info_proxy["GetAttrCurValue"] = &ROGameLibs::BuffLuaInfo::GetAttrCurValue;
#     buff_lua_info_proxy["GetAttrIncrValue"] = &ROGameLibs::BuffLuaInfo::GetAttrIncrValue;
#     buff_lua_info_proxy["AddLuaOutParam"] = &ROGameLibs::BuffLuaInfo::AddLuaOutParam;
#     buff_lua_info_proxy["GetWeatherInfo"] = &ROGameLibs::BuffLuaInfo::GetWeatherInfo;
#     buff_lua_info_proxy["GetTemperatureInfo"] = &ROGameLibs::BuffLuaInfo::GetTemperatureInfo;
#     buff_lua_info_proxy["IsInSkillIdSet"] = &ROGameLibs::BuffLuaInfo::IsInSkillIdSet;
#      // variables
#     equip_single_proxy["before_equip_id"] = &ROGameLibs::EquipSingle::before_equip_id;
#     equip_single_proxy["after_equip_id"] = &ROGameLibs::EquipSingle::after_equip_id;
#     equip_single_proxy["pos"] = &ROGameLibs::EquipSingle::pos;
#     equip_single_proxy["is_disable"] = &ROGameLibs::EquipSingle::is_disable;
#     buff_lua_info_proxy["extend_time_"] = &ROGameLibs::BuffLuaInfo::extend_time_;
#     buff_lua_info_proxy["behit_damage_result_"] = &ROGameLibs::BuffLuaInfo::behit_damage_result_;
#     buff_lua_info_proxy["attack_damage_result_"] = &ROGameLibs::BuffLuaInfo::attack_damage_result_;
#     buff_lua_info_proxy["trigger_timing_"] = &ROGameLibs::BuffLuaInfo::trigger_timing_;
#     buff_lua_info_proxy["caster_snapshot_"] = &ROGameLibs::BuffLuaInfo::caster_snapshot_;
#     buff_lua_info_proxy["before_skill_level_"] = &ROGameLibs::BuffLuaInfo::before_skill_level_;
#     buff_lua_info_proxy["before_profession_"] = &ROGameLibs::BuffLuaInfo::before_profession_;
#     buff_lua_info_proxy["current_skill_id_"] = &ROGameLibs::BuffLuaInfo::current_skill_id_;
#     buff_lua_info_proxy["current_skill_level_"] = &ROGameLibs::BuffLuaInfo::current_skill_level_;
#     buff_lua_info_proxy["current_skill_effect_id_"] = &ROGameLibs::BuffLuaInfo::current_skill_effect_id_;
#     buff_lua_info_proxy["attack_type_"] = &ROGameLibs::BuffLuaInfo::attack_type_;
#     buff_lua_info_proxy["defense_type_"] = &ROGameLibs::BuffLuaInfo::defense_type_;
#     buff_lua_info_proxy["firer_buff_attr_"] = &ROGameLibs::BuffLuaInfo::firer_buff_attr_;
#     buff_lua_info_proxy["target_buff_attr_"] = &ROGameLibs::BuffLuaInfo::target_buff_attr_;
#     buff_lua_info_proxy["current_skill_"] = &ROGameLibs::BuffLuaInfo::current_skill_;
#     buff_lua_info_proxy["after_weapon_type"] = &ROGameLibs::BuffLuaInfo::after_weapon_type;
#     buff_lua_info_proxy["before_weapon_type"] = &ROGameLibs::BuffLuaInfo::before_weapon_type;
#     buff_lua_info_proxy["change_fight_state_"] = &ROGameLibs::BuffLuaInfo::change_fight_state_;
#     buff_lua_info_proxy["dynamic_attr_table_mgr_"] = &ROGameLibs::BuffLuaInfo::dynamic_attr_table_mgr_;
#     buff_lua_info_proxy["host_scene_"] = &ROGameLibs::BuffLuaInfo::host_scene_;
#     buff_lua_info_proxy["trigger_timing_skill_snapshot_"] = &ROGameLibs::BuffLuaInfo::trigger_timing_skill_snapshot_;
#      // enums
#     r_o_game_libs.new_enum("BuffStateType",
#         "kBuffStateType_None", ROGameLibs::BuffStateType::kBuffStateType_None,
#         "kBuffStateType_SuperArmor", ROGameLibs::BuffStateType::kBuffStateType_SuperArmor,
#         "kBuffStateType_Immortal", ROGameLibs::BuffStateType::kBuffStateType_Immortal,
#         "kBuffStateType_Hiding", ROGameLibs::BuffStateType::kBuffStateType_Hiding,
#         "kBuffStateType_Link", ROGameLibs::BuffStateType::kBuffStateType_Link,
#         "kBuffStateType_Transfigure", ROGameLibs::BuffStateType::kBuffStateType_Transfigure,
#         "kBuffStateType_BuffFirerDontUseOwner", ROGameLibs::BuffStateType::kBuffStateType_BuffFirerDontUseOwner,
#         "kBuffStateType_Solo", ROGameLibs::BuffStateType::kBuffStateType_Solo,
#         "kBuffStateType_EnSemble", ROGameLibs::BuffStateType::kBuffStateType_EnSemble,
#         "kBuffStatueType_Debuff_Start", ROGameLibs::BuffStateType::kBuffStatueType_Debuff_Start,
#         "kBuffStatueType_A_Start", ROGameLibs::BuffStateType::kBuffStatueType_A_Start,
#         "kBuffStateType_Poisoning", ROGameLibs::BuffStateType::kBuffStateType_Poisoning,
#         "kBuffStateType_Bleed", ROGameLibs::BuffStateType::kBuffStateType_Bleed,
#         "kBuffStateType_Firing", ROGameLibs::BuffStateType::kBuffStateType_Firing,
#         "kBuffStateType_Curse", ROGameLibs::BuffStateType::kBuffStateType_Curse,
#         "kBuffStateType_Darkness", ROGameLibs::BuffStateType::kBuffStateType_Darkness,
#         "kBuffStateType_Silence", ROGameLibs::BuffStateType::kBuffStateType_Silence,
#         "kBuffStateType_SlowDown", ROGameLibs::BuffStateType::kBuffStateType_SlowDown,
#         "kBuffStateType_Zhenjianbaipodao", ROGameLibs::BuffStateType::kBuffStateType_Zhenjianbaipodao,
#         "kBuffStateType_DebuffFlag", ROGameLibs::BuffStateType::kBuffStateType_DebuffFlag,
#         "kBuffStatueType_A_End", ROGameLibs::BuffStateType::kBuffStatueType_A_End,
#         "kBuffStatueType_B_Start", ROGameLibs::BuffStateType::kBuffStatueType_B_Start,
#         "kBuffStateType_Fear", ROGameLibs::BuffStateType::kBuffStateType_Fear,
#         "kBuffStateType_Immobilize", ROGameLibs::BuffStateType::kBuffStateType_Immobilize,
#         "kBuffStateType_Sleep", ROGameLibs::BuffStateType::kBuffStateType_Sleep,
#         "kBuffStateType_Charm", ROGameLibs::BuffStateType::kBuffStateType_Charm,
#         "kBuffStatueType_B_End", ROGameLibs::BuffStateType::kBuffStatueType_B_End,
#         "kBuffStatueType_C_Start", ROGameLibs::BuffStateType::kBuffStatueType_C_Start,
#         "kBuffStateType_Frozen", ROGameLibs::BuffStateType::kBuffStateType_Frozen,
#         "kBuffStateType_Petrochemical", ROGameLibs::BuffStateType::kBuffStateType_Petrochemical,
#         "kBuffStateType_ReadyToPetrochemical", ROGameLibs::BuffStateType::kBuffStateType_ReadyToPetrochemical,
#         "kBuffStateType_Paralysis", ROGameLibs::BuffStateType::kBuffStateType_Paralysis,
#         "kBuffStatueType_C_End", ROGameLibs::BuffStateType::kBuffStatueType_C_End,
#         "kBuffStatueType_D_Start", ROGameLibs::BuffStateType::kBuffStatueType_D_Start,
#         "kBuffStateType_Stun", ROGameLibs::BuffStateType::kBuffStateType_Stun,
#         "kBuffStatueType_D_End", ROGameLibs::BuffStateType::kBuffStatueType_D_End,
#         "kBuffStatueType_Debuff_End", ROGameLibs::BuffStateType::kBuffStatueType_Debuff_End,
#         "kBuffStateType_Immune_All_Buff", ROGameLibs::BuffStateType::kBuffStateType_Immune_All_Buff,
# );
#     r_o_game_libs.new_enum("BuffTriggerTimeType",
#         "kBuffTTT_Add", ROGameLibs::BuffTriggerTimeType::kBuffTTT_Add,
#         "kBuffTTT_Time", ROGameLibs::BuffTriggerTimeType::kBuffTTT_Time,
#         "kBuffTTT_SomeOneEnter", ROGameLibs::BuffTriggerTimeType::kBuffTTT_SomeOneEnter,
#         "kBuffTTT_BeHit", ROGameLibs::BuffTriggerTimeType::kBuffTTT_BeHit,
#         "kBuffTTT_Attack", ROGameLibs::BuffTriggerTimeType::kBuffTTT_Attack,
#         "kBuffTTT_AttributeSpecialChange", ROGameLibs::BuffTriggerTimeType::kBuffTTT_AttributeSpecialChange,
#         "kBuffTTT_Delete", ROGameLibs::BuffTriggerTimeType::kBuffTTT_Delete,
#         "kBuffTTT_Append", ROGameLibs::BuffTriggerTimeType::kBuffTTT_Append,
#         "kBuffTTT_SomeOneEnter_AnBi", ROGameLibs::BuffTriggerTimeType::kBuffTTT_SomeOneEnter_AnBi,
#         "kBuffTTT_EquipChange", ROGameLibs::BuffTriggerTimeType::kBuffTTT_EquipChange,
#         "kBuffTTT_BeHitBeforeCalculate", ROGameLibs::BuffTriggerTimeType::kBuffTTT_BeHitBeforeCalculate,
#         "kBuffTTT_AttackBeforeCalculate", ROGameLibs::BuffTriggerTimeType::kBuffTTT_AttackBeforeCalculate,
#         "kBuffTTT_KillEntity", ROGameLibs::BuffTriggerTimeType::kBuffTTT_KillEntity,
#         "kBuffTTT_OnAddTime", ROGameLibs::BuffTriggerTimeType::kBuffTTT_OnAddTime,
#         "kBuffTTT_SomeOneEnter_Rect", ROGameLibs::BuffTriggerTimeType::kBuffTTT_SomeOneEnter_Rect,
#         "kBuffTTT_SkillEnd", ROGameLibs::BuffTriggerTimeType::kBuffTTT_SkillEnd,
#         "kBuffTTT_HosterDead", ROGameLibs::BuffTriggerTimeType::kBuffTTT_HosterDead,
#         "kBuffTTT_GetOnBattleVehicle", ROGameLibs::BuffTriggerTimeType::kBuffTTT_GetOnBattleVehicle,
#         "kBuffTTT_GetOffBattleVehicle", ROGameLibs::BuffTriggerTimeType::kBuffTTT_GetOffBattleVehicle,
#         "kBuffTTT_BeatBackEnd", ROGameLibs::BuffTriggerTimeType::kBuffTTT_BeatBackEnd,
#         "kBuffTTT_PassiveSkillLevelChange", ROGameLibs::BuffTriggerTimeType::kBuffTTT_PassiveSkillLevelChange,
#         "kBuffTTT_ChangeJob", ROGameLibs::BuffTriggerTimeType::kBuffTTT_ChangeJob,
#         "kBuffTTT_FightChange", ROGameLibs::BuffTriggerTimeType::kBuffTTT_FightChange,
#         "kBuffTTT_UnserializeFinish", ROGameLibs::BuffTriggerTimeType::kBuffTTT_UnserializeFinish,
#         "kBuffTTT_AttackBeforeJudge", ROGameLibs::BuffTriggerTimeType::kBuffTTT_AttackBeforeJudge,
#         "kBuffTTT_SomeOneEnter_Link", ROGameLibs::BuffTriggerTimeType::kBuffTTT_SomeOneEnter_Link,
#         "kBuffTTT_Environment_Change", ROGameLibs::BuffTriggerTimeType::kBuffTTT_Environment_Change,
#         "kBuffTTT_EntityEnterFight", ROGameLibs::BuffTriggerTimeType::kBuffTTT_EntityEnterFight,
#         "kBuffTTT_EntityOutFight", ROGameLibs::BuffTriggerTimeType::kBuffTTT_EntityOutFight,
#         "kBuffTTT_SkillDetach", ROGameLibs::BuffTriggerTimeType::kBuffTTT_SkillDetach,
#         "kBuffTTT_HaloBuff", ROGameLibs::BuffTriggerTimeType::kBuffTTT_HaloBuff,
#         "kBuffTTT_SkillStart", ROGameLibs::BuffTriggerTimeType::kBuffTTT_SkillStart,
#         "kBuffTTT_Invalid", ROGameLibs::BuffTriggerTimeType::kBuffTTT_Invalid,
# );
